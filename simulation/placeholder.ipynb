# %% [markdown]
# The purpose of this file is just to make sure that the environment is configured and functioning properly. Run some of these cells and make sure you can get outputs to appear.

# %%
from sympy import *
x, y, z = symbols('x y z')

# %%
diff(cos(x), x)
# Out:
# -sin(x)

# %%
diff(exp(x**2), x)
# Out:
# 2*x*exp(x**2)

# %%
p1 = plot(x**2, xlim=(0,2), ylim=(0,5))

# %%
p2 = plot(exp(x**2), x)

# %% [markdown]
# suppose:
# $L = \lim_{x\to 7} f(x)$
